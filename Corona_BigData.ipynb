# %% [markdown]
# <a href="https://colab.research.google.com/github/rlawngus0910/bigdata-subway-visualization/blob/main/Corona_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# !pip install dnspython
# !pip install motor
# Out:
# ...
#      |████████████████████████████████| 245kB 4.3MB/s
# ...
#      |████████████████████████████████| 61kB 3.1MB/s
# ...

# %%
pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 194kB 4.1MB/s
# ...
#   Found existing installation: dnspython 2.1.0
#     Uninstalling dnspython-2.1.0:
#       Successfully uninstalled dnspython-2.1.0
# ...

# %%
pip install dnspython==2.0.0
# Out:
# ...
#      |████████████████████████████████| 215kB 4.3MB/s
# ...
#   Found existing installation: dnspython 1.16.0
#     Uninstalling dnspython-1.16.0:
#       Successfully uninstalled dnspython-1.16.0
# ...

# %%
import pymongo
import dns
import pprint
import motor

client = pymongo.MongoClient("mongodb+srv://Kimjuhyun:rlawngus123@cluster0.b7881.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test
# Out:
# ['bdproject', 'myFirstDatabase', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %%
# !pip install plotly==3.8.1
# !pip install cufflinks
# Out:
# ...
#      |████████████████████████████████| 41.2MB 103kB/s
# ...
# ERROR: cufflinks 0.17.3 has requirement plotly>=4.1.1, but you'll have plotly 3.8.1 which is incompatible.
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...
#      |████████████████████████████████| 13.2MB 4.1MB/s
# ...
#   Found existing installation: plotly 3.8.1
#     Uninstalling plotly-3.8.1:
#       Successfully uninstalled plotly-3.8.1
# ...

# %%
# 지하철 월별 승객 수 (코로나)
import plotly.express as px
import cufflinks as cf
import re
db = client['bdproject']
subway = db['subway']
cursor = subway.aggregate([
    {
        '$match': {
            'use_mon': re.compile(r"2020")
        }
    }, {
        '$group': {
            '_id': '$use_mon', 
            'total0s': {
                '$sum': '$00시-01시 승차인원'
            }, 
            'total0h': {
                '$sum': '$00시-01시 하차인원'
            }, 
            'total1s': {
                '$sum': '$01시-02시 승차인원'
            }, 
            'total1h': {
                '$sum': '$01시-02시 하차인원'
            }, 
            'total2s': {
                '$sum': '$02시-03시 승차인원'
            }, 
            'total2h': {
                '$sum': '$02시-03시 하차인원'
            }, 
            'total3s': {
                '$sum': '$03시-04시 승차인원'
            }, 
            'total3h': {
                '$sum': '$03시-04시 하차인원'
            }, 
            'total4s': {
                '$sum': '$04시-05시 승차인원'
            }, 
            'total4h': {
                '$sum': '$04시-05시 하차인원'
            }, 
            'total5s': {
                '$sum': '$05시-06시 승차인원'
            }, 
            'total5h': {
                '$sum': '$05시-06시 하차인원'
            }, 
            'total6s': {
                '$sum': '$06시-07시 승차인원'
            }, 
            'total6h': {
                '$sum': '$06시-07시 하차인원'
            }, 
            'total7s': {
                '$sum': '$07시-08시 승차인원'
            }, 
            'total7h': {
                '$sum': '$07시-08시 하차인원'
            }, 
            'total8s': {
                '$sum': '$08시-09시 승차인원'
            }, 
            'total8h': {
                '$sum': '$08시-09시 하차인원'
            }, 
            'total9s': {
                '$sum': '$09시-10시 승차인원'
            }, 
            'total9h': {
                '$sum': '$09시-10시 하차인원'
            }, 
            'total10s': {
                '$sum': '$10시-11시 승차인원'
            }, 
            'total10h': {
                '$sum': '$10시-11시 하차인원'
            }, 
            'total11s': {
                '$sum': '$11시-12시 승차인원'
            }, 
            'total11h': {
                '$sum': '$11시-12시 하차인원'
            }, 
            'total12s': {
                '$sum': '$12시-13시 승차인원'
            }, 
            'total12h': {
                '$sum': '$12시-13시 하차인원'
            }, 
            'total13s': {
                '$sum': '$13시-14시 승차인원'
            }, 
            'total13h': {
                '$sum': '$13시-14시 하차인원'
            }, 
            'total14s': {
                '$sum': '$14시-15시 승차인원'
            }, 
            'total14h': {
                '$sum': '$14시-15시 하차인원'
            }, 
            'total15s': {
                '$sum': '$15시-16시 승차인원'
            }, 
            'total15h': {
                '$sum': '$15시-16시 하차인원'
            }, 
            'total16s': {
                '$sum': '$16시-17시 승차인원'
            }, 
            'total16h': {
                '$sum': '$16시-17시 하차인원'
            }, 
            'total17s': {
                '$sum': '$17시-18시 승차인원'
            }, 
            'total17h': {
                '$sum': '$17시-18시 하차인원'
            }, 
            'total18s': {
                '$sum': '$18시-19시 승차인원'
            }, 
            'total18h': {
                '$sum': '$18시-19시 하차인원'
            }, 
            'total19s': {
                '$sum': '$19시-20시 승차인원'
            }, 
            'total19h': {
                '$sum': '$19시-20시 하차인원'
            }, 
            'total20s': {
                '$sum': '$20시-21시 승차인원'
            }, 
            'total20h': {
                '$sum': '$20시-21시 하차인원'
            }, 
            'total21s': {
                '$sum': '$21시-22시 승차인원'
            }, 
            'total21h': {
                '$sum': '$21시-22시 하차인원'
            }, 
            'total22s': {
                '$sum': '$22시-23시 승차인원'
            }, 
            'total22h': {
                '$sum': '$22시-23시 하차인원'
            }, 
            'total23s': {
                '$sum': '$23시-24시 승차인원'
            }, 
            'total23h': {
                '$sum': '$23시-24시 하차인원'
            }
        }
    }, {
        '$addFields': {
            'totalPeople': {
                '$add': [
                    '$total0s', '$total0h', '$total1s', '$total1h', '$total2s', '$total2h', '$total3s', '$total3h', '$total4s', '$total4h', '$total5s', '$total5h', '$total6s', '$total6h', '$total7s', '$total7h', '$total8s', '$total8h', '$total9s', '$total9h', '$total10s', '$total10h', '$total11s', '$total11h', '$total12s', '$total12h', '$total13s', '$total13h', '$total14s', '$total14h', '$total15s', '$total15h', '$total16s', '$total16h', '$total17s', '$total17h', '$total18s', '$total18h', '$total19s', '$total19h', '$total20s', '$total20h', '$total21s', '$total21h', '$total22s', '$total22h', '$total23s', '$total23h'
                ]
            }
        }
    }, {
        '$project': {
            'totalPeople': 1
        }
    } , {
        '$sort' : {
            '_id' : 1
        }
    }
])

people_per_month = pd.DataFrame(list(cursor))

fig = px.line(people_per_month,
              x = "_id",
              y = "totalPeople"
              )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import re
corona = db['corona']
cursor01 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202001")
        }
    }, {
        '$count': '확진일'
    }
])

cursor02 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202002")
        }
    }, {
        '$count': '확진일'
    }
])

cursor03 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202003")
        }
    }, {
        '$count': '확진일'
    }
])

cursor04 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202004")
        }
    }, {
        '$count': '확진일'
    }
])

cursor05 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202005")
        }
    }, {
        '$count': '확진일'
    }
])

cursor06 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202006")
        }
    }, {
        '$count': '확진일'
    }
])

cursor07 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202007")
        }
    }, {
        '$count': '확진일'
    }
])

cursor08 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202008")
        }
    }, {
        '$count': '확진일'
    }
])

cursor09 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202009")
        }
    }, {
        '$count': '확진일'
    }
])

cursor10 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202010")
        }
    }, {
        '$count': '확진일'
    }
])

cursor11 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202011")
        }
    }, {
        '$count': '확진일'
    }
])

cursor12 = corona.aggregate([
    {
        '$match': {
            '확진일': re.compile(r"202012")
        }
    }, {
        '$count': '확진일'
    }
])

_id = ['202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010', '202011', '202012']
df_month = pd.DataFrame(_id,columns=['_id'])

df01 = pd.DataFrame(list(cursor01))
df02 = pd.DataFrame(list(cursor02))
df03 = pd.DataFrame(list(cursor03))
df04 = pd.DataFrame(list(cursor04))
df05 = pd.DataFrame(list(cursor05))
df06 = pd.DataFrame(list(cursor06))
df07 = pd.DataFrame(list(cursor07))
df08 = pd.DataFrame(list(cursor08))
df09 = pd.DataFrame(list(cursor09))
df10 = pd.DataFrame(list(cursor10))
df11 = pd.DataFrame(list(cursor11))
df12 = pd.DataFrame(list(cursor12))

month_result = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11,df12])
month_result['_id'] = _id 

corona_people = pd.merge(df, month_result)

fig = px.bar(month_result, 
            x = "_id",
            y = "확진일",
            color="_id"
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 2020년 총 승객 수
import re
cursor = subway.aggregate([
    {
        '$match': {
            'line_num': re.compile(r"선"), 
            'use_mon': re.compile(r"2020")
        }
    }, {
        '$group': {
            '_id': '$line_num', 
            'total0s': {
                '$sum': '$00시-01시 승차인원'
            }, 
            'total0h': {
                '$sum': '$00시-01시 하차인원'
            }, 
            'total1s': {
                '$sum': '$01시-02시 승차인원'
            }, 
            'total1h': {
                '$sum': '$01시-02시 하차인원'
            }, 
            'total2s': {
                '$sum': '$02시-03시 승차인원'
            }, 
            'total2h': {
                '$sum': '$02시-03시 하차인원'
            }, 
            'total3s': {
                '$sum': '$03시-04시 승차인원'
            }, 
            'total3h': {
                '$sum': '$03시-04시 하차인원'
            }, 
            'total4s': {
                '$sum': '$04시-05시 승차인원'
            }, 
            'total4h': {
                '$sum': '$04시-05시 하차인원'
            }, 
            'total5s': {
                '$sum': '$05시-06시 승차인원'
            }, 
            'total5h': {
                '$sum': '$05시-06시 하차인원'
            }, 
            'total6s': {
                '$sum': '$06시-07시 승차인원'
            }, 
            'total6h': {
                '$sum': '$06시-07시 하차인원'
            }, 
            'total7s': {
                '$sum': '$07시-08시 승차인원'
            }, 
            'total7h': {
                '$sum': '$07시-08시 하차인원'
            }, 
            'total8s': {
                '$sum': '$08시-09시 승차인원'
            }, 
            'total8h': {
                '$sum': '$08시-09시 하차인원'
            }, 
            'total9s': {
                '$sum': '$09시-10시 승차인원'
            }, 
            'total9h': {
                '$sum': '$09시-10시 하차인원'
            }, 
            'total10s': {
                '$sum': '$10시-11시 승차인원'
            }, 
            'total10h': {
                '$sum': '$10시-11시 하차인원'
            }, 
            'total11s': {
                '$sum': '$11시-12시 승차인원'
            }, 
            'total11h': {
                '$sum': '$11시-12시 하차인원'
            }, 
            'total12s': {
                '$sum': '$12시-13시 승차인원'
            }, 
            'total12h': {
                '$sum': '$12시-13시 하차인원'
            }, 
            'total13s': {
                '$sum': '$13시-14시 승차인원'
            }, 
            'total13h': {
                '$sum': '$13시-14시 하차인원'
            }, 
            'total14s': {
                '$sum': '$14시-15시 승차인원'
            }, 
            'total14h': {
                '$sum': '$14시-15시 하차인원'
            }, 
            'total15s': {
                '$sum': '$15시-16시 승차인원'
            }, 
            'total15h': {
                '$sum': '$15시-16시 하차인원'
            }, 
            'total16s': {
                '$sum': '$16시-17시 승차인원'
            }, 
            'total16h': {
                '$sum': '$16시-17시 하차인원'
            }, 
            'total17s': {
                '$sum': '$17시-18시 승차인원'
            }, 
            'total17h': {
                '$sum': '$17시-18시 하차인원'
            }, 
            'total18s': {
                '$sum': '$18시-19시 승차인원'
            }, 
            'total18h': {
                '$sum': '$18시-19시 하차인원'
            }, 
            'total19s': {
                '$sum': '$19시-20시 승차인원'
            }, 
            'total19h': {
                '$sum': '$19시-20시 하차인원'
            }, 
            'total20s': {
                '$sum': '$20시-21시 승차인원'
            }, 
            'total20h': {
                '$sum': '$20시-21시 하차인원'
            }, 
            'total21s': {
                '$sum': '$21시-22시 승차인원'
            }, 
            'total21h': {
                '$sum': '$21시-22시 하차인원'
            }, 
            'total22s': {
                '$sum': '$22시-23시 승차인원'
            }, 
            'total22h': {
                '$sum': '$22시-23시 하차인원'
            }, 
            'total23s': {
                '$sum': '$23시-24시 승차인원'
            }, 
            'total23h': {
                '$sum': '$23시-24시 하차인원'
            }
        }
    }, {
        '$addFields': {
            'totalPeople2020': {
                '$add': [
                    '$total0s', '$total0h', '$total1s', '$total1h', '$total2s', '$total2h', '$total3s', '$total3h', '$total4s', '$total4h', '$total5s', '$total5h', '$total6s', '$total6h', '$total7s', '$total7h', '$total8s', '$total8h', '$total9s', '$total9h', '$total10s', '$total10h', '$total11s', '$total11h', '$total12s', '$total12h', '$total13s', '$total13h', '$total14s', '$total14h', '$total15s', '$total15h', '$total16s', '$total16h', '$total17s', '$total17h', '$total18s', '$total18h', '$total19s', '$total19h', '$total20s', '$total20h', '$total21s', '$total21h', '$total22s', '$total22h', '$total23s', '$total23h'
                ]
            }
        }
    }, {
        '$project': {
            'totalPeople2020': 1
        }
    }
])

total_people_2020 = pd.DataFrame(list(cursor))

# %%
cursor2 = subway.aggregate([
    {
        '$match': {
            'line_num': re.compile(r"선"), 
            'use_mon': re.compile(r"2019")
        }
    }, {
        '$group': {
            '_id': '$line_num', 
            'total0s': {
                '$sum': '$00시-01시 승차인원'
            }, 
            'total0h': {
                '$sum': '$00시-01시 하차인원'
            }, 
            'total1s': {
                '$sum': '$01시-02시 승차인원'
            }, 
            'total1h': {
                '$sum': '$01시-02시 하차인원'
            }, 
            'total2s': {
                '$sum': '$02시-03시 승차인원'
            }, 
            'total2h': {
                '$sum': '$02시-03시 하차인원'
            }, 
            'total3s': {
                '$sum': '$03시-04시 승차인원'
            }, 
            'total3h': {
                '$sum': '$03시-04시 하차인원'
            }, 
            'total4s': {
                '$sum': '$04시-05시 승차인원'
            }, 
            'total4h': {
                '$sum': '$04시-05시 하차인원'
            }, 
            'total5s': {
                '$sum': '$05시-06시 승차인원'
            }, 
            'total5h': {
                '$sum': '$05시-06시 하차인원'
            }, 
            'total6s': {
                '$sum': '$06시-07시 승차인원'
            }, 
            'total6h': {
                '$sum': '$06시-07시 하차인원'
            }, 
            'total7s': {
                '$sum': '$07시-08시 승차인원'
            }, 
            'total7h': {
                '$sum': '$07시-08시 하차인원'
            }, 
            'total8s': {
                '$sum': '$08시-09시 승차인원'
            }, 
            'total8h': {
                '$sum': '$08시-09시 하차인원'
            }, 
            'total9s': {
                '$sum': '$09시-10시 승차인원'
            }, 
            'total9h': {
                '$sum': '$09시-10시 하차인원'
            }, 
            'total10s': {
                '$sum': '$10시-11시 승차인원'
            }, 
            'total10h': {
                '$sum': '$10시-11시 하차인원'
            }, 
            'total11s': {
                '$sum': '$11시-12시 승차인원'
            }, 
            'total11h': {
                '$sum': '$11시-12시 하차인원'
            }, 
            'total12s': {
                '$sum': '$12시-13시 승차인원'
            }, 
            'total12h': {
                '$sum': '$12시-13시 하차인원'
            }, 
            'total13s': {
                '$sum': '$13시-14시 승차인원'
            }, 
            'total13h': {
                '$sum': '$13시-14시 하차인원'
            }, 
            'total14s': {
                '$sum': '$14시-15시 승차인원'
            }, 
            'total14h': {
                '$sum': '$14시-15시 하차인원'
            }, 
            'total15s': {
                '$sum': '$15시-16시 승차인원'
            }, 
            'total15h': {
                '$sum': '$15시-16시 하차인원'
            }, 
            'total16s': {
                '$sum': '$16시-17시 승차인원'
            }, 
            'total16h': {
                '$sum': '$16시-17시 하차인원'
            }, 
            'total17s': {
                '$sum': '$17시-18시 승차인원'
            }, 
            'total17h': {
                '$sum': '$17시-18시 하차인원'
            }, 
            'total18s': {
                '$sum': '$18시-19시 승차인원'
            }, 
            'total18h': {
                '$sum': '$18시-19시 하차인원'
            }, 
            'total19s': {
                '$sum': '$19시-20시 승차인원'
            }, 
            'total19h': {
                '$sum': '$19시-20시 하차인원'
            }, 
            'total20s': {
                '$sum': '$20시-21시 승차인원'
            }, 
            'total20h': {
                '$sum': '$20시-21시 하차인원'
            }, 
            'total21s': {
                '$sum': '$21시-22시 승차인원'
            }, 
            'total21h': {
                '$sum': '$21시-22시 하차인원'
            }, 
            'total22s': {
                '$sum': '$22시-23시 승차인원'
            }, 
            'total22h': {
                '$sum': '$22시-23시 하차인원'
            }, 
            'total23s': {
                '$sum': '$23시-24시 승차인원'
            }, 
            'total23h': {
                '$sum': '$23시-24시 하차인원'
            }
        }
    }, {
        '$addFields': {
            'totalPeople2019': {
                '$add': [
                    '$total0s', '$total0h', '$total1s', '$total1h', '$total2s', '$total2h', '$total3s', '$total3h', '$total4s', '$total4h', '$total5s', '$total5h', '$total6s', '$total6h', '$total7s', '$total7h', '$total8s', '$total8h', '$total9s', '$total9h', '$total10s', '$total10h', '$total11s', '$total11h', '$total12s', '$total12h', '$total13s', '$total13h', '$total14s', '$total14h', '$total15s', '$total15h', '$total16s', '$total16h', '$total17s', '$total17h', '$total18s', '$total18h', '$total19s', '$total19h', '$total20s', '$total20h', '$total21s', '$total21h', '$total22s', '$total22h', '$total23s', '$total23h'
                ]
            }
        }
    }, {
        '$project': {
            'totalPeople2019': 1
        }
    }
])

total_people_2019 = pd.DataFrame(list(cursor2))

# %%
result = pd.merge(total_people_2020,total_people_2019)

fig = px.bar(result,
              x = "_id",
              y = ["totalPeople2019","totalPeople2020"],
              barmode = 'group',
              )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
